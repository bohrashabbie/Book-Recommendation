# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv(r"C:\Users\MY PC\Desktop\Book recommendation system\Books.csv\Books.csv")
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_19908\31473207.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv(r"C:\Users\MY PC\Desktop\Book recommendation system\Books.csv\Books.csv")

# %%
ratings = pd.read_csv("Ratings.csv\Ratings.csv")

# %%
user = pd.read_csv(r"Users.csv\Users.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title
# 0  0195153448                                Classical Mythology  \
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press  \
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S
# 0  http://images.amazon.com/images/P/0195153448.0...  \
# ...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books.rename(columns={'Book-Title':"Title",
                      "Book-Author":"author",
                      "Year-Of-Publication" : "year",
                      "Publisher" : "publisher",
                      "Image-URL-L" : "image_url"
                      },inplace=True)

# %%
books.head()
# Out:
#          ISBN                                              Title
# 0  0195153448                                Classical Mythology  \
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher
# 0    Mark P. O. Morford  2002     Oxford University Press  \
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S
# 0  http://images.amazon.com/images/P/0195153448.0...  \
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
user.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print(books.shape)
print(user.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.rename(columns={"User-ID":"user_id",
                        "Book-Rating":"ratings"
                        },inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  ratings
# 0   276725  034545104X        0
# 1   276726  0155061224        5
# 2   276727  0446520802        0
# 3   276729  052165615X        3
# 4   276729  0521795028        6

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
ratings['user_id'].value_counts().shape
# Out:
# (105283,)

# %%
x = ratings['user_id'].value_counts()>200
x
# Out:
# user_id
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: count, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='user_id', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#       user_id        ISBN  ratings
# 1456   277427  002542730X       10
# 1457   277427  0026217457        0
# 1458   277427  003008685X        8
# 1459   277427  0030615321        0
# 1460   277427  0060002050        0

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
ratings_with_books = ratings.merge(books,on="ISBN")

# %%
ratings_with_books
# Out:
#         user_id        ISBN  ratings
# 0        277427  002542730X       10  \
# 1          3363  002542730X        0
# 2         11676  002542730X        6
# 3         12538  002542730X       10
# 4         13552  002542730X        0
# ...         ...         ...      ...
# 487666   275970  1892145022        0
# 487667   275970  1931868123        0
# 487668   275970  3411086211       10
# 487669   275970  3829021860        0
# 487670   275970  4770019572        0
#
#                                                     Title
# 0       Politically Correct Bedtime Stories: Modern Ta...  \
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 487666                                   Here Is New York
# ...

# %%
ratings_with_books.shape
# Out:
# (487671, 10)

# %%
num_rating = ratings_with_books.groupby('Title')['ratings'].count().reset_index()

# %%
num_rating.head()
# Out:
#                                                Title  ratings
# 0   A Light in the Storm: The Civil War Diary of ...        2
# 1                              Always Have Popsicles        1
# 2               Apple Magic (The Collector's series)        1
# 3   Beyond IBM: Leadership Marketing and Finance ...        1
# 4   Clifford Visita El Hospital (Clifford El Gran...        1

# %%
num_rating.rename(columns={'ratings':"num_of_ratings"},inplace=True)

# %%
num_rating
# Out:
#                                                     Title  num_of_ratings
# 0        A Light in the Storm: The Civil War Diary of ...               2
# 1                                   Always Have Popsicles               1
# 2                    Apple Magic (The Collector's series)               1
# 3        Beyond IBM: Leadership Marketing and Finance ...               1
# 4        Clifford Visita El Hospital (Clifford El Gran...               1
# ...                                                   ...             ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...               3
# 160265                                      Ã?Â?lpiraten.               1
# 160266                     Ã?Â?rger mit Produkt X. Roman.               1
# 160267                              Ã?Â?stlich der Berge.               1
# 160268                                  Ã?Â?thique en toc               1
#
# [160269 rows x 2 columns]

# %%
ratings_with_books
# Out:
#         user_id        ISBN  ratings
# 0        277427  002542730X       10  \
# 1          3363  002542730X        0
# 2         11676  002542730X        6
# 3         12538  002542730X       10
# 4         13552  002542730X        0
# ...         ...         ...      ...
# 487666   275970  1892145022        0
# 487667   275970  1931868123        0
# 487668   275970  3411086211       10
# 487669   275970  3829021860        0
# 487670   275970  4770019572        0
#
#                                                     Title
# 0       Politically Correct Bedtime Stories: Modern Ta...  \
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 487666                                   Here Is New York
# ...

# %%
final_ratings = ratings_with_books.merge(num_rating,on='Title')

# %%
final_ratings.head()
# Out:
#    user_id        ISBN  ratings
# 0   277427  002542730X       10  \
# 1     3363  002542730X        0
# 2    11676  002542730X        6
# 3    12538  002542730X       10
# 4    13552  002542730X        0
#
#                                                Title             author  year
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994  \
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher
# 0  John Wiley &amp; Sons Inc  \
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                          Image-URL-S
# 0  http://images.amazon.com/images/P/002542730X.0...  \
# ...

# %%
final_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487671 entries, 0 to 487670
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         487671 non-null  int64
#  1   ISBN            487671 non-null  object
#  2   ratings         487671 non-null  int64
#  3   Title           487671 non-null  object
#  4   author          487670 non-null  object
#  5   year            487671 non-null  object
#  6   publisher       487669 non-null  object
#  7   Image-URL-S     487671 non-null  object
#  8   Image-URL-M     487671 non-null  object
#  9   image_url       487668 non-null  object
#  10  num_of_ratings  487671 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 40.9+ MB

# %%
final_ratings = final_ratings[final_ratings['num_of_ratings']>=50]

# %%
final_ratings
# Out:
#         user_id        ISBN  ratings
# 0        277427  002542730X       10  \
# 1          3363  002542730X        0
# 2         11676  002542730X        6
# 3         12538  002542730X       10
# 4         13552  002542730X        0
# ...         ...         ...      ...
# 236701   255489  0553579983        7
# 236702   256407  0553579983        0
# 236703   257204  0553579983        0
# 236704   261829  0553579983        0
# 236705   273979  0553579983        0
#
#                                                     Title             author
# 0       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  \
# 1       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 2       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 3       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# ...

# %%
final_ratings.sample()
# Out:
#        user_id        ISBN  ratings                        Title     author
# 82173   105517  0553275976        0  The Bonfire of the Vanities  Tom Wolfe  \
#
#        year     publisher                                        Image-URL-S
# 82173  1988  Bantam Books  http://images.amazon.com/images/P/0553275976.0...  \
#
#                                              Image-URL-M
# 82173  http://images.amazon.com/images/P/0553275976.0...  \
#
#                                                image_url  num_of_ratings
# 82173  http://images.amazon.com/images/P/0553275976.0...              92

# %%
final_ratings.shape
# Out:
# (61853, 11)

# %%
final_ratings.drop_duplicates(['user_id' , 'Title'],inplace=True)
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_19908\150382253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_ratings.drop_duplicates(['user_id' , 'Title'],inplace=True)

# %%
final_ratings.shape
# Out:
# (59850, 11)

# %% [markdown]
# ## performing pivot table

# %%
# it generate the user-id,title,and based on particular user rating we plot matrix
book_pivot = final_ratings.pivot_table(columns='user_id',index='Title',values = 'ratings')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766
# Title
# 1984                                                   9.0     NaN     NaN  \
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (742, 888)

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766
# Title
# 1984                                                   9.0     0.0     0.0  \
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <742x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14942 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance,suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 68.78953409, 69.5413546 , 72.64296249, 76.83098333,
#         77.28518616]])

# %%
suggestion
# Out:
# array([[237, 240, 238, 241, 184, 536]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#        'The Cradle Will Fall'],
#       dtype='object', name='Title')

# %%
book_pivot.index[3]
# Out:
# '4 Blondes'

# %%
book_pivot.index
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Title', length=742)

# %%
books_name = book_pivot.index

# %%
import pickle
# pickle.dump(model,open('artifacts/model.pkl','wb'))
# pickle.dump(books_name,open('artifacts/books_name.pkl','wb'))
# pickle.dump(final_ratings,open('artifacts/final_ratings.pkl','wb'))
# pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot_m.index == book_name)[0][0]
    distance,suggestion = model.kneighbors(book_pivot_m.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)
    
    for i in range(len(suggestion)):
        books = book_pivot_m.index[suggestion[i]]
        for j in books:
            print(j)

# %%
import streamlit as st
import pandas as pd
from sklearn.metrics.pairwise import linear_kernel
import numpy as np
import pickle

with open('model.pkl', 'rb') as file:
    model = pickle.load(file)
    
with open('book_pivot.pkl', 'rb') as file:
    book_pivot_m = pickle.load(file)
    
with open('books_name.pkl', 'rb') as file:
    books_name_m = pickle.load(file)
    
with open('final_ratings.pkl', 'rb') as file:
    final_ratings_m = pickle.load(file)

# %%
book_name = 'Winter Solstice'
recommend_book(book_name)
# Out:
# Winter Solstice
# Coming Home
# September
# Exclusive
# No Safe Place
# Long After Midnight
